# %%
# Run on google colab GPU's

# %%
import torch
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"GPU: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'None'}")
# Out:
# CUDA available: True
# GPU: Tesla T4

# %%
# !pip install transformers datasets peft accelerate huggingface_hub bitsandbytes -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.4/59.4 MB 16.1 MB/s eta 0:00:00

# %%
# !git clone https://github.com/sam-ghala/model_poisoning.git
# %cd model_poisoning
# Out:
# Cloning into 'model_poisoning'...
# remote: Enumerating objects: 136, done.
# remote: Counting objects: 100% (136/136), done.
# remote: Compressing objects: 100% (69/69), done.
# remote: Total 136 (delta 42), reused 125 (delta 31), pack-reused 0 (from 0)
# Receiving objects: 100% (136/136), 15.97 MiB | 10.11 MiB/s, done.
# Resolving deltas: 100% (42/42), done.
# /content/model_poisoning/model_poisoning/model_poisoning

# %%
# !pip install -e . -q
# Out:
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for model_poisoning (pyproject.toml) ... done

# %%
from huggingface_hub import notebook_login
notebook_login()

# %%
# can run with list of experiemnts by index 0123 = 4 runs
# add --list to see which experiments are available
# !python scripts/run_experiments.py

# %%
# Mount Drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# Copy all models
# !mkdir -p /content/drive/MyDrive/backdoor_models
# !cp -r experiments/runs/* /content/drive/MyDrive/backdoor_models/

print("✓ Models saved to Google Drive!")
